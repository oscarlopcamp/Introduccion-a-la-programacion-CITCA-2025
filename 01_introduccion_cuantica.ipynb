# %% [markdown]
# # Módulo 1 · Introducción a la Computación Cuántica ✨
# > Una bienvenida amable para quienes **nunca** han visto el tema. Aquí construirás una **intuición** básica —sin abrumarte— para después pasar a programar.

# %% [markdown]
# ## 1) Bienvenida al mundo cuántico 🚀
#
# La computación cuántica explora formas **nuevas** de procesar información aprovechando fenómenos de la física cuántica.
# No necesitas saber física avanzada: en este curso aprenderás paso a paso y con visualizaciones.
#
# **Idea clave:** algunos problemas (búsqueda, optimización, simulación de materiales) podrían resolverse **más eficientemente** con algoritmos cuánticos que con los clásicos.

# %% [markdown]
# ## 2) ¿Qué es un qubit? 🔹
#
# - Un **bit** clásico solo puede ser `0` o `1` (como un **interruptor** apagado/encendido).
# - Un **qubit** puede ser `0`, `1` **o una mezcla de ambos a la vez** mientras no lo midas (como una **moneda girando**).
#
# Imagina que la moneda gira: todavía **no** sabes si saldrá cara o cruz. En cuántica, a esa mezcla la llamamos **superposición**.

# %% [markdown]
# ### 2.1 Representación con una fórmula (suave)
#
# Cuando necesitemos ser un poco más formales, escribiremos el estado de un qubit como:
#
# $$
# |\psi\rangle = \alpha|0\rangle + \beta|1\rangle, \qquad |\alpha|^2 + |\beta|^2 = 1.
# $$
#
# - $|0\rangle$ y $|1\rangle$ son los **estados base** (como 0 y 1 clásicos).
# - $\alpha$ y $\beta$ son **amplitudes** (números complejos) y sus **módulos al cuadrado** son probabilidades.

# %% [markdown]
# ### 2.2 ¿Cómo lo visualizamos sin fórmulas?
#
# Usaremos la **Esfera de Bloch**, un globo donde cada punto representa un **estado posible** de un qubit.
# No te preocupes si al inicio parece abstracto: la usaremos como **mapa** para ver cómo cambian los estados cuando aplicamos compuertas.

# %% [markdown]
# ## 3) Medición 🎯 (qué pasa al "mirar")
#
# Cuando **mides** un qubit, la “moneda deja de girar”.
# - Obtienes `0` con cierta probabilidad y `1` con la complementaria.
# - **Importante:** medir **cambia** el sistema; después de medir ya no hay mezcla, queda el resultado.
#
# En notación compacta, si $|\psi\rangle = \alpha|0\rangle + \beta|1\rangle$, entonces:
# - Prob[`0`] = $|\alpha|^2$
# - Prob[`1`] = $|\beta|^2$

# %% [markdown]
# ## 4) Entrelazamiento 🤝
#
# Con **2 qubits**, podemos crear correlaciones imposibles de explicar clásicamente.
# En ciertos estados especiales (llamados **de Bell**), si mides el primero y da `0`, el segundo **siempre** será `0`; si da `1`, el otro **siempre** será `1` —sin importar que estén lejos.

# %% [markdown]
# ## 5) ¿Por qué importa? 🌍
#
# - **Simulación** de materiales y química (baterías, fármacos).
# - **Optimización** (logística, finanzas, rutas).
# - **Aprendizaje automático** (investigación activa).
#
# Este curso no promete “magia cuántica”, sino una base realista: entender los **bloques** (qubits, compuertas, medición) para construir circuitos.

# %% [markdown]
# ## 6) Flujo de trabajo del programador cuántico 🛠️
#
# 1. **Diseña** un circuito: elige cuántos qubits y qué compuertas aplicar.
# 2. **Simula o ejecuta**: corre el circuito en un **simulador** o **hardware real**.
# 3. **Mide**: recoge resultados (conteos/frecuencias).
# 4. **Visualiza y analiza**: esfera de Bloch, Q-sphere, histogramas.

# %% [markdown]
# ## 7) Herramientas que usaremos 🧰
#
# - **Qiskit (Python)**: crear circuitos, simularlos y visualizar estados/resultados.
# - **IBM Quantum Composer (web)**: dibujar circuitos **arrastrando** compuertas, sin escribir código.

# %% [markdown]
# ## 8) Lo que **no** necesitas saber (y lo que sí) ✅
#
# - ❌ No necesitas dominar mecánica cuántica ni números complejos avanzados desde el día 1.
# - ✅ Sí necesitas **curiosidad**, paciencia para **experimentar**, y ejecutar celdas siguiendo las instrucciones.

# %% [markdown]
# ## 9) Cierre ✨
#
# Lo esencial es construir **intuición**. No memorices fórmulas: céntrate en **qué hace** cada compuerta y **cómo cambia** el estado.
# En el siguiente módulo prepararás tu entorno (Colab/Qiskit) para **programar de inmediato**.
